# %%
import numpy as np
import random
import matplotlib.pyplot as plt 
import math

# %%
#Observation to be written, top one is wrong.this one seems right
n=10000
Xn=[]
x=[]
for i in range(0,n):
    if(i==0):
        Xn.append(random.randint(-1,1))
    else:
        Xn.append(Xn[i-1]+random.randint(-1,1))

for i in range(0,n):
    x.append(i)
plt.plot(x,Xn)
